# %% [markdown]
# # ADIVINA LA FRASE
#
# Implementad un algoritmo genético que encuentre la frase (con caracteres ASCII) introducida
# al ejecutar el algoritmo.
# - El algoritmo genético no conoce la frase, pero la función de fitness sí.
# - Los caracteres ASCII se pueden representar como valores enteros del 0 al 255. En
# Python: chr(65) == ‘A’, ord(‘A’) == 65

# %%
import random

class GeneticAlgorithm(object):
    def __init__(self, genetics):
        self.genetics = genetics
        pass

    def run(self):
        population = self.genetics.initial()
        while True:
            fits_pops = [(self.genetics.fitness(ch),  ch) for ch in population]
            if self.genetics.check_stop(fits_pops): break
            population = self.next(fits_pops)
            pass
        return population

    def next(self, fits):
        parents_generator = self.genetics.parents(fits)
        size = len(fits)
        nexts = []
        while len(nexts) < size:
            parents = next(parents_generator)
            cross = random.random() < self.genetics.probability_crossover()
            children = self.genetics.crossover(parents) if cross else parents
            for ch in children:
                mutate = random.random() < self.genetics.probability_mutation()
                nexts.append(self.genetics.mutation(ch) if mutate else ch)
                pass
            pass
        return nexts[0:size]
    pass

class GeneticFunctions(object):
    def probability_crossover(self):
        r"""returns rate of occur crossover(0.0-1.0)"""
        return 1.0

    def probability_mutation(self):
        r"""returns rate of occur mutation(0.0-1.0)"""
        return 0.0

    def initial(self):
        r"""returns list of initial population
        """
        return []

    def fitness(self, chromosome):
        r"""returns domain fitness value of chromosome
        """
        return len(chromosome)

    def check_stop(self, fits_populations):
        r"""stop run if returns True
        - fits_populations: list of (fitness_value, chromosome)
        """
        return False

    def parents(self, fits_populations):
        r"""generator of selected parents
        """
        gen = iter(sorted(fits_populations))
        while True:
            f1, ch1 = next(gen)
            f2, ch2 = next(gen)
            yield (ch1, ch2)
            pass
        return

    def crossover(self, parents):
        r"""breed children
        """
        return parents

    def mutation(self, chromosome):
        r"""mutate chromosome
        """
        return chromosome
    pass

if __name__ == "__main__":
    """
    example: Mapped guess prepared Text
    """
    class GuessText(GeneticFunctions):
        def __init__(self, target_text,
                     limit=2000, size=400,
                     prob_crossover=0.9, prob_mutation=0.2):
            self.target = self.text2chromo(target_text)
            self.counter = 0

            self.limit = limit
            self.size = size
            self.prob_crossover = prob_crossover
            self.prob_mutation = prob_mutation
            pass

        # GeneticFunctions interface impls
        def probability_crossover(self):
            return self.prob_crossover

        def probability_mutation(self):
            return self.prob_mutation

        def initial(self):
            return [self.random_chromo() for j in range(self.size)]

        def fitness(self, chromo):
            # larger is better, matched == 0
            return -sum(abs(c - t) for c, t in zip(chromo, self.target))

        def check_stop(self, fits_populations):
            self.counter += 1
            if self.counter % 10 == 0:
                best_match = list(sorted(fits_populations))[-1][1]
                fits = [f for f, ch in fits_populations]
                best = max(fits)
                worst = min(fits)
                ave = sum(fits) / len(fits)
                print(
                    "[G %3d] score=(%4d, %4d, %4d): %r" %
                    (self.counter, best, ave, worst,
                     self.chromo2text(best_match)))
                pass
            return self.counter >= self.limit

        def parents(self, fits_populations):
            while True:
                father = self.tournament(fits_populations)
                mother = self.tournament(fits_populations)
                yield (father, mother)
                pass
            pass

        def crossover(self, parents):
            father, mother = parents
            index1 = random.randint(1, len(self.target) - 2)
            index2 = random.randint(1, len(self.target) - 2)
            if index1 > index2: index1, index2 = index2, index1
            child1 = father[:index1] + mother[index1:index2] + father[index2:]
            child2 = mother[:index1] + father[index1:index2] + mother[index2:]
            return (child1, child2)

        def mutation(self, chromosome):
            index = random.randint(0, len(self.target) - 1)
            vary = random.randint(-5, 5)
            mutated = list(chromosome)
            mutated[index] += vary
            return mutated

        # internals
        def tournament(self, fits_populations):
            alicef, alice = self.select_random(fits_populations)
            bobf, bob = self.select_random(fits_populations)
            return alice if alicef > bobf else bob

        def select_random(self, fits_populations):
            return fits_populations[random.randint(0, len(fits_populations)-1)]

        def text2chromo(self, text):
            return [ord(ch) for ch in text]
        def chromo2text(self, chromo):
            return "".join(chr(max(1, min(ch, 255))) for ch in chromo)

        def random_chromo(self):
            return [random.randint(1, 255) for i in range(len(self.target))]
        pass

    GeneticAlgorithm(GuessText("Estamos hablando de tonterias muy grandes!")).run()
    pass
# Out:
# [G  10] score=(-1373, -1890, -2379): "7KrQk\x9a\x9e>\x8f\x8b3(v@wZ'\x87_\x03!ÅsWSY¢t^\tBeB,Z¤\x98V\x947/\x1a"
# [G  20] score=(-819, -1097, -1460): '6S2aku\x8d\x05_\x8b_RNHwj%h|1W>|b~\x8cptx\x06RkU%Yt}{{\x84\x800'
# [G  30] score=(-525, -668, -842): 'I\x7fuakut\x16_\x8e\\RIgVZ%hc1\x88wswD\x8aqtn\x12qpU!]o}{{]\x92\x19'
# [G  40] score=(-400, -465, -543): 'I\x7fuapuu\x16oh_RfgY{$hc1\x88koba[nmn,qpU!Wtg{{]\x92\x19'
# [G  50] score=(-315, -352, -390): "I\x7fudkuu'__^SfdY{ hc1yiotc[nmn)qp\x8e!]rc{j]\x92\x19"
# [G  60] score=(-276, -298, -323): 'I\x7fuakit\x16kh_Vfg]k ec1yootc[nmn)qp\x8e!]scuf]\x92\x19'
# [G  70] score=(-228, -255, -279): "6yuakut'l__Vfg]k ec1wootc[ihn)qu\x8a!]rcwf]t-"
# [G  80] score=(-202, -220, -237): "6|vakuu'j_cVfg^k ec1tnotc`ims)mu\x87!brcwfft-"
# [G  90] score=(-164, -187, -208): '?\x7fuakut"j__Xaebj ec,uootcdihs)mu\x81!bscwfft-'
# [G 100] score=(-137, -152, -171): '>yuakus"i_cXfkbo dc,uootcdihs$mu\x82!frcufat*'
# [G 110] score=(-110, -123, -139): ':tuakpt"k__\\akbo dc\'uootdgihs$mu\x82!frbqfft*'
# [G 120] score=( -82,  -99, -119): "?tuakpt\x1fk^bbakbo ec'uoothli`s!mu\x81!frbofft*"
# [G 130] score=( -65,  -76,  -91): '>uuakpt"i^bbakbo dc\'uooteqics mu\x80!grcofft '
# [G 140] score=( -46,  -56,  -68): '>uuampt\x1fj_bbanbo df#uooteri`s mu|!grbocft '
# [G 150] score=( -34,  -41,  -54): 'Duuamps i_bgakdo df#uooterias!mux!grbofft$'
# [G 160] score=( -20,  -30,  -40): 'Dsuamps i`blando dc#uooterias!mux!graocft '
# [G 170] score=( -15,  -19,  -26): 'Dsuampt i`blando dc uooterias mux!graodft!'
# [G 180] score=( -11,  -14,  -22): 'Dsuamps i`blando df tooterias muy!graodft!'
# [G 190] score=(  -6,  -10,  -17): 'Dstamos h`blando df tonterias muy!grandft!'
# [G 200] score=(  -4,   -6,  -13): 'Dstamos hbblando de tonterias muy granddt!'
# [G 210] score=(  -3,   -4,  -10): 'Dstamos h`blando de tonterias muy!grandes!'
# [G 220] score=(  -1,   -3,   -9): 'Dstamos hablando de tonterias muy grandes!'
# [G 230] score=(  -1,   -1,   -6): 'Dstamos hablando de tonterias muy grandes!'
# [G 240] score=(   0,   -1,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 250] score=(   0,   -1,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 260] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 270] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 280] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 290] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 300] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 310] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 320] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 330] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 340] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 350] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 360] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 370] score=(   0,    0,  -10): 'Estamos hablando de tonterias muy grandes!'
# [G 380] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 390] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 400] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 410] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 420] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 430] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 440] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 450] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 460] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 470] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 480] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 490] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 500] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 510] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 520] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 530] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 540] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 550] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 560] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 570] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 580] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 590] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 600] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 610] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 620] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 630] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 640] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 650] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 660] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 670] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 680] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 690] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 700] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 710] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 720] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 730] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 740] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 750] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 760] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 770] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 780] score=(   0,    0,  -10): 'Estamos hablando de tonterias muy grandes!'
# [G 790] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 800] score=(   0,    0,  -10): 'Estamos hablando de tonterias muy grandes!'
# [G 810] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 820] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 830] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 840] score=(   0,    0,  -10): 'Estamos hablando de tonterias muy grandes!'
# [G 850] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 860] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 870] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 880] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 890] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 900] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 910] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 920] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 930] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 940] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 950] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 960] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 970] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 980] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 990] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1000] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1010] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1020] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1030] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1040] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1050] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1060] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1070] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1080] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1090] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1100] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1110] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1120] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1130] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1140] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1150] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1160] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1170] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1180] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1190] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1200] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1210] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1220] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1230] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1240] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1250] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1260] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1270] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1280] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1290] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1300] score=(   0,    0,  -10): 'Estamos hablando de tonterias muy grandes!'
# [G 1310] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1320] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1330] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1340] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1350] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1360] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1370] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1380] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1390] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1400] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1410] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1420] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1430] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1440] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1450] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1460] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1470] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1480] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1490] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1500] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1510] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1520] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1530] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1540] score=(   0,    0,  -10): 'Estamos hablando de tonterias muy grandes!'
# [G 1550] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1560] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1570] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1580] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1590] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1600] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1610] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1620] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1630] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1640] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1650] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1660] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1670] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1680] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1690] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1700] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1710] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1720] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1730] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1740] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1750] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1760] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1770] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1780] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1790] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1800] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1810] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1820] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1830] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1840] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1850] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1860] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1870] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1880] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1890] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1900] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1910] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 1920] score=(   0,    0,   -9): 'Estamos hablando de tonterias muy grandes!'
# [G 1930] score=(   0,    0,   -7): 'Estamos hablando de tonterias muy grandes!'
# [G 1940] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1950] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1960] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1970] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
# [G 1980] score=(   0,    0,   -6): 'Estamos hablando de tonterias muy grandes!'
# [G 1990] score=(   0,    0,   -8): 'Estamos hablando de tonterias muy grandes!'
# [G 2000] score=(   0,    0,   -5): 'Estamos hablando de tonterias muy grandes!'
